# %% [markdown]
# # Generating the data

# %% [markdown]
# Importing necessary libraries

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

warnings.filterwarnings("ignore")
sns.set_style("whitegrid")
sns.set_palette(sns.color_palette("blend:blue,orange"))

# %% [markdown]
# Generating

# %%
x_uniform: np.array = np.array([np.random.uniform(-1, 1, 1500), np.random.uniform(-1, 1, 1500)])
x_normal: np.array = np.array([
    np.concatenate([
        np.random.normal(0, .2, 500), 
        np.random.normal(1, .2, 500),
        np.random.normal(-0.7, .2, 500),
        np.random.normal(1, .2, 500)
    ]), 
    np.concatenate([
        np.random.normal(0, .2, 500), 
        np.random.normal(1, .2, 500),
        np.random.normal(-2, .2, 500),
        np.random.normal(0, .2, 500)
    ])])

sns.scatterplot(*x_normal);

# %%
def plot(hue: np.array, x: np.array):

    sns.scatterplot(*x, hue=hue, palette = ["red", "blue", "green", "orange"])
    plt.show()

# %%
model: KMeans = KMeans(n_clusters=4)

plot(model.fit_predict(x_normal.T), x_normal)
plot(model.fit_predict(x_uniform.T), x_uniform)

# %% [markdown]
# # no u
